# %%
class Roommate:
    def __init__(self,name,age,studentid,course,college):
        self.name=name
        self.age=age
        self.studentid=studentid
        self.course=course
        self.college=college
    def describe_roommate(self):
        print("The description of my roommate is:")
        print(f"My roommate name is- {self.name}")
        print(f"My roommate age is- {self.age}")
        print(f"My roommate student ID is- {self.studentid}")
        print(f"My roommate course is- {self.course}")
        print(f"My roommate college is- {self.college}")
        
my_roommate=Roommate("Martin Dajoo",20,"ENC221-0103/2023","Geomatic Engineering","COETEC") 
my_roommate.describe_roommate()
# Out:
# The description of my roommate is:
# My roommate name is- Martin Dajoo
# My roommate age is- 20
# My roommate student ID is- ENC221-0103/2023
# My roommate course is- Geomatic Engineering
# My roommate college is- COETEC
